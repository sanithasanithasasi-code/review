# %%
import pandas as pd

# %%
#q1
df=pd.read_csv("/content/drive/MyDrive/Data analytics/Review/netflix_titles.csv")

# %%
#q2
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
#Q3
df.shape
# Out:
# (8807, 12)

# %%
#Q4
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#Q5
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#Q6
df["rating"].nunique()
# Out:
# 17

# %%
#Q7
df[df['type']=="Movie"]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
#Q8
df[df['country']=="India"]
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %%
#Q9
df[df['release_year']>2015]
# Out:
#      show_id     type                      title         director  \
# 0         s1    Movie       Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# ...      ...      ...                        ...              ...
# 8787   s8788    Movie  You Can’t Fight Christmas      Kenny Young
# 8794   s8795    Movie                     اشتباك     Mohamed Diab
# 8796   s8797  TV Show                 Yunus Emre              NaN
# 8797   s8798  TV Show                  Zak Storm              NaN
# 8803   s8804  TV Show                Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
#Q10
df[df['title'].str.contains("Love")]
# Out:
#      show_id     type                           title  \
# 25       s26  TV Show            Love on the Spectrum
# 158     s159    Movie         Love Don't Cost a Thing
# 159     s160    Movie                  Love in a Puff
# 206     s207    Movie       LSD: Love, Sex Aur Dhokha
# 227     s228    Movie                     Really Love
# ...      ...      ...                             ...
# 8567   s8568  TV Show  The Year of Happiness and Love
# 8575   s8576  TV Show                 This Is My Love
# 8649   s8650    Movie           Two Lovers and a Bear
# 8721   s8722  TV Show                   What Is Love?
# 8725   s8726    Movie            What's Up With Love?
#
#                        director  \
# 25                          NaN
# 158                   Troy Byer
# 159              Pang Ho-cheung
# 206            Dibakar Banerjee
# 227       Angel Kristi Williams
# ...                         ...
# 8567                        NaN
# 8575                        NaN
# ...

# %%
#Q11
df[df['duration'].str.contains("min",na=False)]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
#Q12
df.dropna(subset=["director"])
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
#Q13
df["country"].fillna("unknown",inplace=True)
# Out:
# /tmp/ipykernel_12818/2506534301.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["country"].fillna("unknown",inplace=True)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#Q14
df["cast"].isnull().sum()
# Out:
# np.int64(825)

# %%
#Q15
df["rating"].fillna("not rated")
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
#Q16
df['date_added']=pd.to_datetime(df["date_added"],format="mixed")

# %%
#Q17
df["year_added"]=df['date_added'].dt.year

# %%
df['date_added'].head()
# Out:
# 0   2021-09-25
# 1   2021-09-24
# 2   2021-09-24
# 3   2021-09-24
# 4   2021-09-24
# Name: date_added, dtype: datetime64[ns]

# %%
#Q18
df["month_name"]=df['date_added'].dt.month_name()

# %%
#Q19
df[df['date_added'].dt.year==2020].shape[0]
# Out:
# 1879

# %%
df["year_added"]
# Out:
# 0       2021.0
# 1       2021.0
# 2       2021.0
# 3       2021.0
# 4       2021.0
#          ...
# 8802    2019.0
# 8803    2019.0
# 8804    2019.0
# 8805    2020.0
# 8806    2019.0
# Name: year_added, Length: 8807, dtype: float64

# %%
#Q20
df["date_added"].dt.month_name().value_counts().max()
# Out:
# 827

# %%
#Q21
df["release_year"].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1961       1
# 1925       1
# 1959       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %%
# 22
df.groupby("type").size()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %%
# 24
df["country"].value_counts().head(3)
# Out:
# country
# United States    2818
# India             972
# unknown           831
# Name: count, dtype: int64

# %%
# 25
df[df["type"]=="TV Show"].groupby(df["date_added"].dt.year).size()
# Out:
# date_added
# 2008.0      1
# 2013.0      5
# 2014.0      5
# 2015.0     26
# 2016.0    176
# 2017.0    349
# 2018.0    412
# 2019.0    592
# 2020.0    595
# 2021.0    505
# dtype: int64

# %%
# 26
df[df["director"].str.contains("Martin", case=False, na=False)]
# Out:
#      show_id   type                                              title  \
# 143     s144  Movie                                      Green Lantern
# 149     s150  Movie                                  I Got the Hook Up
# 579     s580  Movie                                       Midnight Run
# 903     s904  Movie                                            Nayattu
# 944     s945  Movie                                    S.M.A.R.T Chase
# 1089   s1090  Movie                              Two Distant Strangers
# 1358   s1359  Movie                                     Shutter Island
# 1642   s1643  Movie                                          The Beast
# 1736   s1737  Movie                           Operation Christmas Drop
# 2632   s2633  Movie                       No Direction Home: Bob Dylan
# 2860   s2861  Movie                                               Hugo
# 3227   s3228  Movie                                       The Irishman
# ...

# %%
# 27
df["first_actor"] = df["cast"].str.split(",").str[0]

# %%
# 28
df[df["listed_in"].str.contains("Comedy")].shape[0]
# Out:
# 399

# %%
# 29
df["title_length"] = df["title"].str.len()

# %%
# 30
df["listed_in"] = df["listed_in"].str.lower()

# %%
# 31
df.sort_values("release_year", ascending=False)
# Out:
#      show_id     type                                          title  \
# 1         s2  TV Show                                  Blood & Water
# 2         s3  TV Show                                      Ganglands
# 3         s4  TV Show                          Jailbirds New Orleans
# 31       s32  TV Show                             Chicago Party Aunt
# 30       s31    Movie                                Ankahi Kahaniya
# ...      ...      ...                                            ...
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#                                                director  \
# 1                                                   NaN
# ...

# %%
#32
df["release_year"].min()
df["release_year"].max()
# Out:
# 2021

# %%
# 33
df.sort_values("title")[["title"]].head()
# Out:
#                               title
# 2036                         #Alive
# 2304  #AnneFrank - Parallel Stories
# 2481              #FriendButMarried
# 2324            #FriendButMarried 2
# 5973                          #Roxy

# %%
# 34
df.set_index("show_id", inplace=True)

# %%
# 35
df.reset_index(inplace=True)

# %%
# 36
df["content_age"] = 2024 - df["release_year"]

# %%
# 37
df["is_movie"] = df["type"] == "Movie"

# %%
# 42
df[(df["director"]=="Christopher Nolan") &
   (df["country"].str.contains("United States", na=False))]
# Out:
#     show_id   type      title           director  \
# 340    s341  Movie  Inception  Christopher Nolan
#
#                                                   cast  \
# 340  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
#
#                            country date_added  release_year rating duration  \
# 340  United States, United Kingdom 2021-08-01          2010  PG-13  148 min
#
#                                            listed_in  \
# 340  action & adventure, sci-fi & fantasy, thrillers
#
#                                            description  year_added month_name  \
# 340  A troubled thief who extracts secrets from peo...      2021.0     August
#
#            first_actor  title_length  content_age  is_movie
# 340  Leonardo DiCaprio             9           14      True

# %%
43
df[(df["listed_in"].str.contains("Drama|Thriller", case=False, na=False)) &
   (df["release_year"]==2021)]
# Out:
#      show_id     type                          title             director  \
# 1         s2  TV Show                  Blood & Water                  NaN
# 5         s6  TV Show                  Midnight Mass        Mike Flanagan
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 15       s16  TV Show              Dear White People                  NaN
# ...      ...      ...                            ...                  ...
# 1410   s1411    Movie  Tribhanga - Tedhi Medhi Crazy       Renuka Shahane
# 1412   s1413    Movie                       Wish You          Sung Do-jun
# 1431   s1432    Movie                    Stuck Apart                  NaN
# 1448   s1449  TV Show                      Cobra Kai                  NaN
# 1460   s1461  TV Show                        Monarca                  NaN
#
#                                                    cast  \
# ...

# %%
# 44
df[df["cast"].str.contains("Tom Hanks", case=False, na=False)].shape[0]
# Out:
# 8

# %%
# 45
df["listed_in"].str.split(", ").explode().value_counts().max()
# Out:
# 2752

# %%
# 46
df.groupby(["rating","type"]).size()
# Out:
# rating    type
# 66 min    Movie         1
# 74 min    Movie         1
# 84 min    Movie         1
# G         Movie        41
# NC-17     Movie         3
# NR        Movie        75
#           TV Show       5
# PG        Movie       287
# PG-13     Movie       490
# R         Movie       797
#           TV Show       2
# TV-14     Movie      1427
#           TV Show     733
# TV-G      Movie       126
#           TV Show      94
# TV-MA     Movie      2062
#           TV Show    1145
# TV-PG     Movie       540
#           TV Show     323
# TV-Y      Movie       131
#           TV Show     176
# TV-Y7     Movie       139
#           TV Show     195
# TV-Y7-FV  Movie         5
#           TV Show       1
# UR        Movie         3
# dtype: int64

# %%
# 47
df[(df["date_added"].dt.month==1) &
   (df["release_year"]<2010)]
# Out:
#      show_id   type                    title          director  \
# 1422   s1423  Movie                 Apaharan       Prakash Jha
# 1423   s1424  Movie             BluffMaster!       Rohan Sippy
# 1426   s1427  Movie                Gangaajal       Prakash Jha
# 1441   s1442  Movie            Hello Brother       Sohail Khan
# 1447   s1448  Movie                  Case 39  Christian Alvart
# ...      ...    ...                      ...               ...
# 8764   s8765  Movie               Wyatt Earp   Lawrence Kasdan
# 8766   s8767  Movie                      XXx         Rob Cohen
# 8767   s8768  Movie  XXX: State of the Union      Lee Tamahori
# 8773   s8774  Movie      Yanda Kartavya Aahe      Kedar Shinde
# 8805   s8806  Movie                     Zoom      Peter Hewitt
#
#                                                    cast  \
# 1422  Ajay Devgn, Nana Patekar, Bipasha Basu, Ayub K...
# 1423  Abhishek Bachchan, Priyanka Chopra, Riteish De...
# ...

# %%
# 48
(df.isnull().sum()/len(df))*100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          0.000000
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# year_added       0.113546
# month_name       0.113546
# first_actor      9.367549
# title_length     0.000000
# content_age      0.000000
# is_movie         0.000000
# dtype: float64

# %%
# 49
df["director"].value_counts().head()
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Name: count, dtype: int64
