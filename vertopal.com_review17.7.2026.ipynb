# %% [markdown]
# # EDA ASSIGNMENT QUESTION AND ANSWERS<a href="#EDA-ASSIGNMENT-QUESTION-AND-ANSWERS" class="anchor-link">¶</a>
#
# In \[1\]:
#
#     import pandas as pd
#     import numpy as np
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     import warnings
#     warnings.filterwarnings("ignore")
#
# In \[2\]:
#
#     df=pd.read_csv(r"C:\Users\SANITHA\Downloads\diabetes_dataset.csv")
#
# ## SECTION 1:DATA UNDERSTANDING & STRUCTURE<a href="#SECTION-1:DATA-UNDERSTANDING-&amp;-STRUCTURE"
# class="anchor-link">¶</a>
#
# ### QS 1<a href="#QS-1" class="anchor-link">¶</a>
#
# In \[3\]:
#
#     df
#
# Out\[3\]:
#
# |       | age | gender | ethnicity | education_level | income_level | employment_status | smoking_status | alcohol_consumption_per_week | physical_activity_minutes_per_week | diet_score | ... | hdl_cholesterol | ldl_cholesterol | triglycerides | glucose_fasting | glucose_postprandial | insulin_level | hba1c | diabetes_risk_score | diabetes_stage | diagnosed_diabetes |
# |-------|-----|--------|-----------|-----------------|--------------|-------------------|----------------|------------------------------|------------------------------------|------------|-----|-----------------|-----------------|---------------|-----------------|----------------------|---------------|-------|---------------------|----------------|--------------------|
# | 0     | 58  | Male   | Asian     | Highschool      | Lower-Middle | Employed          | Never          | 0                            | 215                                | 5.7        | ... | 41              | 160             | 145           | 136             | 236                  | 6.36          | 8.18  | 29.6                | Type 2         | 1                  |
# | 1     | 48  | Female | White     | Highschool      | Middle       | Employed          | Former         | 1                            | 143                                | 6.7        | ... | 55              | 50              | 30            | 93              | 150                  | 2.00          | 5.63  | 23.0                | No Diabetes    | 0                  |
# | 2     | 60  | Male   | Hispanic  | Highschool      | Middle       | Unemployed        | Never          | 1                            | 57                                 | 6.4        | ... | 66              | 99              | 36            | 118             | 195                  | 5.07          | 7.51  | 44.7                | Type 2         | 1                  |
# | 3     | 74  | Female | Black     | Highschool      | Low          | Retired           | Never          | 0                            | 49                                 | 3.4        | ... | 50              | 79              | 140           | 139             | 253                  | 5.28          | 9.03  | 38.2                | Type 2         | 1                  |
# | 4     | 46  | Male   | White     | Graduate        | Middle       | Retired           | Never          | 1                            | 109                                | 7.2        | ... | 52              | 125             | 160           | 137             | 184                  | 12.74         | 7.20  | 23.5                | Type 2         | 1                  |
# | ...   | ... | ...    | ...       | ...             | ...          | ...               | ...            | ...                          | ...                                | ...        | ... | ...             | ...             | ...           | ...             | ...                  | ...           | ...   | ...                 | ...            | ...                |
# | 99995 | 46  | Male   | Other     | Graduate        | Upper-Middle | Unemployed        | Former         | 1                            | 136                                | 8.3        | ... | 45              | 150             | 116           | 113             | 109                  | 14.58         | 5.55  | 26.0                | Pre-Diabetes   | 0                  |
# | 99996 | 41  | Female | White     | Graduate        | Middle       | Employed          | Never          | 3                            | 76                                 | 8.8        | ... | 55              | 123             | 146           | 96              | 146                  | 9.02          | 5.97  | 24.4                | Pre-Diabetes   | 0                  |
# | 99997 | 57  | Female | Black     | No formal       | Upper-Middle | Employed          | Former         | 4                            | 121                                | 9.9        | ... | 50              | 111             | 184           | 93              | 132                  | 2.57          | 5.21  | 27.6                | No Diabetes    | 0                  |
# | 99998 | 47  | Female | Black     | Highschool      | Lower-Middle | Retired           | Never          | 3                            | 52                                 | 5.9        | ... | 68              | 91              | 116           | 106             | 117                  | 9.81          | 5.53  | 26.4                | Pre-Diabetes   | 0                  |
# | 99999 | 52  | Female | White     | Postgraduate    | Middle       | Employed          | Never          | 1                            | 248                                | 2.7        | ... | 31              | 183             | 87            | 91              | 142                  | 15.93         | 5.73  | 27.9                | Pre-Diabetes   | 0                  |
#
# 100000 rows × 31 columns
#
# In \[4\]:
#
#     df.shape
#
# Out\[4\]:
#
#     (100000, 31)
#
# In \[5\]:
#
#     df.columns
#
# Out\[5\]:
#
#     Index(['age', 'gender', 'ethnicity', 'education_level', 'income_level',
#            'employment_status', 'smoking_status', 'alcohol_consumption_per_week',
#            'physical_activity_minutes_per_week', 'diet_score',
#            'sleep_hours_per_day', 'screen_time_hours_per_day',
#            'family_history_diabetes', 'hypertension_history',
#            'cardiovascular_history', 'bmi', 'waist_to_hip_ratio', 'systolic_bp',
#            'diastolic_bp', 'heart_rate', 'cholesterol_total', 'hdl_cholesterol',
#            'ldl_cholesterol', 'triglycerides', 'glucose_fasting',
#            'glucose_postprandial', 'insulin_level', 'hba1c', 'diabetes_risk_score',
#            'diabetes_stage', 'diagnosed_diabetes'],
#           dtype='object')
#
# In \[6\]:
#
#     df.dtypes
#
# Out\[6\]:
#
#     age                                     int64
#     gender                                 object
#     ethnicity                              object
#     education_level                        object
#     income_level                           object
#     employment_status                      object
#     smoking_status                         object
#     alcohol_consumption_per_week            int64
#     physical_activity_minutes_per_week      int64
#     diet_score                            float64
#     sleep_hours_per_day                   float64
#     screen_time_hours_per_day             float64
#     family_history_diabetes                 int64
#     hypertension_history                    int64
#     cardiovascular_history                  int64
#     bmi                                   float64
#     waist_to_hip_ratio                    float64
#     systolic_bp                             int64
#     diastolic_bp                            int64
#     heart_rate                              int64
#     cholesterol_total                       int64
#     hdl_cholesterol                         int64
#     ldl_cholesterol                         int64
#     triglycerides                           int64
#     glucose_fasting                         int64
#     glucose_postprandial                    int64
#     insulin_level                         float64
#     hba1c                                 float64
#     diabetes_risk_score                   float64
#     diabetes_stage                         object
#     diagnosed_diabetes                      int64
#     dtype: object
#
# In \[7\]:
#
#     df.select_dtypes(include="number").columns
#
# Out\[7\]:
#
#     Index(['age', 'alcohol_consumption_per_week',
#            'physical_activity_minutes_per_week', 'diet_score',
#            'sleep_hours_per_day', 'screen_time_hours_per_day',
#            'family_history_diabetes', 'hypertension_history',
#            'cardiovascular_history', 'bmi', 'waist_to_hip_ratio', 'systolic_bp',
#            'diastolic_bp', 'heart_rate', 'cholesterol_total', 'hdl_cholesterol',
#            'ldl_cholesterol', 'triglycerides', 'glucose_fasting',
#            'glucose_postprandial', 'insulin_level', 'hba1c', 'diabetes_risk_score',
#            'diagnosed_diabetes'],
#           dtype='object')
#
# In \[8\]:
#
#     df.select_dtypes(include="object").columns
#
# Out\[8\]:
#
#     Index(['gender', 'ethnicity', 'education_level', 'income_level',
#            'employment_status', 'smoking_status', 'diabetes_stage'],
#           dtype='object')
#
# ### QS 2<a href="#QS-2" class="anchor-link">¶</a>
#
# In \[9\]:
#
#     df.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 100000 entries, 0 to 99999
#     Data columns (total 31 columns):
#      #   Column                              Non-Null Count   Dtype
#     ---  ------                              --------------   -----
#      0   age                                 100000 non-null  int64
#      1   gender                              100000 non-null  object
#      2   ethnicity                           100000 non-null  object
#      3   education_level                     100000 non-null  object
#      4   income_level                        100000 non-null  object
#      5   employment_status                   100000 non-null  object
#      6   smoking_status                      100000 non-null  object
#      7   alcohol_consumption_per_week        100000 non-null  int64
#      8   physical_activity_minutes_per_week  100000 non-null  int64
#      9   diet_score                          100000 non-null  float64
#      10  sleep_hours_per_day                 100000 non-null  float64
#      11  screen_time_hours_per_day           100000 non-null  float64
#      12  family_history_diabetes             100000 non-null  int64
#      13  hypertension_history                100000 non-null  int64
#      14  cardiovascular_history              100000 non-null  int64
#      15  bmi                                 100000 non-null  float64
#      16  waist_to_hip_ratio                  100000 non-null  float64
#      17  systolic_bp                         100000 non-null  int64
#      18  diastolic_bp                        100000 non-null  int64
#      19  heart_rate                          100000 non-null  int64
#      20  cholesterol_total                   100000 non-null  int64
#      21  hdl_cholesterol                     100000 non-null  int64
#      22  ldl_cholesterol                     100000 non-null  int64
#      23  triglycerides                       100000 non-null  int64
#      24  glucose_fasting                     100000 non-null  int64
#      25  glucose_postprandial                100000 non-null  int64
#      26  insulin_level                       100000 non-null  float64
#      27  hba1c                               100000 non-null  float64
#      28  diabetes_risk_score                 100000 non-null  float64
#      29  diabetes_stage                      100000 non-null  object
#      30  diagnosed_diabetes                  100000 non-null  int64
#     dtypes: float64(8), int64(16), object(7)
#     memory usage: 23.7+ MB
#
# In \[10\]:
#
#     df.describe()
#
# Out\[10\]:
#
# |       | age          | alcohol_consumption_per_week | physical_activity_minutes_per_week | diet_score    | sleep_hours_per_day | screen_time_hours_per_day | family_history_diabetes | hypertension_history | cardiovascular_history | bmi           | ... | cholesterol_total | hdl_cholesterol | ldl_cholesterol | triglycerides | glucose_fasting | glucose_postprandial | insulin_level | hba1c         | diabetes_risk_score | diagnosed_diabetes |
# |-------|--------------|------------------------------|------------------------------------|---------------|---------------------|---------------------------|-------------------------|----------------------|------------------------|---------------|-----|-------------------|-----------------|-----------------|---------------|-----------------|----------------------|---------------|---------------|---------------------|--------------------|
# | count | 100000.00000 | 100000.000000                | 100000.000000                      | 100000.000000 | 100000.000000       | 100000.000000             | 100000.000000           | 100000.000000        | 100000.000000          | 100000.000000 | ... | 100000.000000     | 100000.000000   | 100000.000000   | 100000.000000 | 100000.00000    | 100000.000000        | 100000.000000 | 100000.000000 | 100000.000000       | 100000.000000      |
# | mean  | 50.12041     | 2.003670                     | 118.911640                         | 5.994787      | 6.997818            | 5.996468                  | 0.219410                | 0.250800             | 0.079200               | 25.612653     | ... | 185.978110        | 54.042790       | 103.000430      | 121.462650    | 111.11712       | 160.035050           | 9.061242      | 6.520776      | 30.222362           | 0.599980           |
# | std   | 15.60460     | 1.417779                     | 84.409662                          | 1.780954      | 1.094622            | 2.468406                  | 0.413849                | 0.433476             | 0.270052               | 3.586705      | ... | 32.013005         | 10.267374       | 33.390256       | 43.372619     | 13.59561        | 30.935472            | 4.954060      | 0.813921      | 9.061505            | 0.489904           |
# | min   | 18.00000     | 0.000000                     | 0.000000                           | 0.000000      | 3.000000            | 0.500000                  | 0.000000                | 0.000000             | 0.000000               | 15.000000     | ... | 100.000000        | 20.000000       | 50.000000       | 30.000000     | 60.00000        | 70.000000            | 2.000000      | 4.000000      | 2.700000            | 0.000000           |
# | 25%   | 39.00000     | 1.000000                     | 57.000000                          | 4.800000      | 6.300000            | 4.300000                  | 0.000000                | 0.000000             | 0.000000               | 23.200000     | ... | 164.000000        | 47.000000       | 78.000000       | 91.000000     | 102.00000       | 139.000000           | 5.090000      | 5.970000      | 23.800000           | 0.000000           |
# | 50%   | 50.00000     | 2.000000                     | 100.000000                         | 6.000000      | 7.000000            | 6.000000                  | 0.000000                | 0.000000             | 0.000000               | 25.600000     | ... | 186.000000        | 54.000000       | 102.000000      | 121.000000    | 111.00000       | 160.000000           | 8.790000      | 6.520000      | 29.000000           | 1.000000           |
# | 75%   | 61.00000     | 3.000000                     | 160.000000                         | 7.200000      | 7.700000            | 7.700000                  | 0.000000                | 1.000000             | 0.000000               | 28.000000     | ... | 208.000000        | 61.000000       | 126.000000      | 151.000000    | 120.00000       | 181.000000           | 12.450000     | 7.070000      | 35.600000           | 1.000000           |
# | max   | 90.00000     | 10.000000                    | 833.000000                         | 10.000000     | 10.000000           | 16.800000                 | 1.000000                | 1.000000             | 1.000000               | 39.200000     | ... | 318.000000        | 98.000000       | 263.000000      | 344.000000    | 172.00000       | 287.000000           | 32.220000     | 9.800000      | 67.200000           | 1.000000           |
#
# 8 rows × 24 columns
#
# ### QS 3<a href="#QS-3" class="anchor-link">¶</a>
#
# In \[11\]:
#
#     df.isnull().sum()
#
# Out\[11\]:
#
#     age                                   0
#     gender                                0
#     ethnicity                             0
#     education_level                       0
#     income_level                          0
#     employment_status                     0
#     smoking_status                        0
#     alcohol_consumption_per_week          0
#     physical_activity_minutes_per_week    0
#     diet_score                            0
#     sleep_hours_per_day                   0
#     screen_time_hours_per_day             0
#     family_history_diabetes               0
#     hypertension_history                  0
#     cardiovascular_history                0
#     bmi                                   0
#     waist_to_hip_ratio                    0
#     systolic_bp                           0
#     diastolic_bp                          0
#     heart_rate                            0
#     cholesterol_total                     0
#     hdl_cholesterol                       0
#     ldl_cholesterol                       0
#     triglycerides                         0
#     glucose_fasting                       0
#     glucose_postprandial                  0
#     insulin_level                         0
#     hba1c                                 0
#     diabetes_risk_score                   0
#     diabetes_stage                        0
#     diagnosed_diabetes                    0
#     dtype: int64
#
# ### QS 4<a href="#QS-4" class="anchor-link">¶</a>
#
# In \[12\]:
#
#     df.duplicated().sum()
#
# Out\[12\]:
#
#     np.int64(0)
#
# ### QS 5<a href="#QS-5" class="anchor-link">¶</a>
#
# In \[13\]:
#
#     df["diagnosed_diabetes"].value_counts()
#
# Out\[13\]:
#
#     diagnosed_diabetes
#     1    59998
#     0    40002
#     Name: count, dtype: int64
#
# -   it is used when you want to predict whether a person has diabetes or
#     not
# -   it is a binary classification target variable
# -   usually, 0=no Diabetes and 1=Diabetes
#
# In \[14\]:
#
#     df["diabetes_stage"].value_counts()
#
# Out\[14\]:
#
#     diabetes_stage
#     Type 2          59774
#     Pre-Diabetes    31845
#     No Diabetes      7981
#     Gestational       278
#     Type 1            122
#     Name: count, dtype: int64
#
# -   You want to predict the stage or type of diabetes
# -   You need to know which category a patient belongs to
# -   it is used to multi classification beacause there are multiple
#     classes
#
# ## SECTION 2: UNIVARIATE ANALYSIS<a href="#SECTION-2:-UNIVARIATE-ANALYSIS" class="anchor-link">¶</a>
#
# ### QS 6<a href="#QS-6" class="anchor-link">¶</a>
#
# In \[15\]:
#
#     df["age"].value_counts()
#
# Out\[15\]:
#
#     age
#     52    2517
#     51    2510
#     49    2494
#     53    2482
#     50    2476
#           ...
#     84     241
#     86     191
#     87     165
#     88     154
#     89     117
#     Name: count, Length: 73, dtype: int64
#
# In \[16\]:
#
#     plt.figure(figsize=(10,5))
#     plt.hist(df["age"],bins=10,color="g",edgecolor="brown")
#     plt.xlabel("age"),
#     plt.ylabel("frequency")
#     plt.title("DISTRIBUTION OF AGE")
#     plt.show()
#
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# ### QS 7<a href="#QS-7" class="anchor-link">¶</a>
#
# In \[17\]:
#
#     plt.figure(figsize=(10,5))
#     plt.hist(df["bmi"],bins=10,color="b",edgecolor="white")
#     plt.xlabel("BMI")
#     plt.ylabel("Frequency")
#     plt.title("BMI OF DISTRIBUTION")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[18\]:
#
#     plt.figure(figsize=(10,5))
#     plt.hist(df["hba1c"],bins=10,color="r",edgecolor="pink")
#     plt.xlabel("HbA1c")
#     plt.ylabel("Frequency")
#     plt.title("HbA1c OF DISTRIBUTION")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[19\]:
#
#     plt.figure(figsize=(10,5))
#     plt.hist(df["glucose_fasting"],bins=10,color="brown",edgecolor="pink")
#     plt.xlabel("glucose_fasting")
#     plt.ylabel("Frequency")
#     plt.title("glucose fast OF DISTRIBUTION")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[20\]:
#
#     plt.figure(figsize=(10,5))
#     plt.hist(df["glucose_postprandial"],bins=10,color="y",edgecolor="pink")
#     plt.xlabel("glucose_postprandial")
#     plt.ylabel("Frequency")
#     plt.title("glucose postprandial OF DISTRIBUTION")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# ### QS 8<a href="#QS-8" class="anchor-link">¶</a>
#
# In \[21\]:
#
#     plt.figure(figsize=(15,8))
#     plt.subplot(2,2,1)
#     df["gender"].value_counts().plot(kind="bar",color="orange",edgecolor="g",)
#     plt.title("GENDER DISTRIBUTION")
#     plt.xlabel("GENDER")
#     plt.ylabel("Frequency")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[22\]:
#
#     plt.figure(figsize=(18,8))
#     plt.subplot(2,2,1)
#     df["ethnicity"].value_counts().plot(kind="bar",color="orange",edgecolor="g",)
#     plt.title("ETHNICITY DISTRIBUTION")
#     plt.xlabel("Ethnicity")
#     plt.ylabel("Frequency")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[23\]:
#
#     plt.figure(figsize=(18,8))
#     plt.subplot(2,2,1)
#     df["smoking_status"].value_counts().plot(kind="bar",color="orange",edgecolor="g",)
#     plt.title("SMOKING STATUS DISTRIBUTION")
#     plt.xlabel("Smoking status")
#     plt.ylabel("Frequency")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[24\]:
#
#     plt.figure(figsize=(18,8))
#     plt.subplot(2,2,1)
#     df["employment_status"].value_counts().plot(kind="bar",color="orange",edgecolor="g",)
#     plt.title("DISTRIBUTION FOR EMPLOYMENT STATUS")
#     plt.xlabel("Employment status")
#     plt.ylabel("Frequency")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# -   Gender: The other category has very few records compared to male and
#     female
# -   Ethnicity: The white category has a much higher count than the other
#     ethnicngroups
# -   Smoking Status: The never category has the highest count,making the
#     distribution imbalanced
# -   Employment status: The employed category has the highest count,while
#     student has the lowest count,indicating imbalance
#
# ### QS 9<a href="#QS-9" class="anchor-link">¶</a>
#
# In \[25\]:
#
#     df["diabetes_stage"].value_counts()
#
# Out\[25\]:
#
#     diabetes_stage
#     Type 2          59774
#     Pre-Diabetes    31845
#     No Diabetes      7981
#     Gestational       278
#     Type 1            122
#     Name: count, dtype: int64
#
# In \[26\]:
#
#     df["diabetes_stage"].value_counts().plot(kind="bar",color="g",edgecolor="purple")
#
# Out\[26\]:
#
#     <Axes: xlabel='diabetes_stage'>
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# -   The dataset is not balanced across the diabetes stages.
# -   Type 2 Diabetes has the highest number of records,while Type 1
#     Diabetes have very few records
#
# -   The dataset is imbalanced across the diabetes stages.
# -   This is important for later modeling because the machine learning
#     model may become based towards the majority classes,such as Type 2
#     diabetes
# -   It may not accurately predict the minority classes,such as Type 1
#     Diabetes and gestational Diabetes. This can reduce the overall
#     performance of the model
#
# ## SECTION 3: OUTLIER DETECTION<a href="#SECTION-3:-OUTLIER-DETECTION" class="anchor-link">¶</a>
#
# ### QS 11<a href="#QS-11" class="anchor-link">¶</a>
#
# In \[27\]:
#
#     df["insulin_level"]
#
# Out\[27\]:
#
#     0         6.36
#     1         2.00
#     2         5.07
#     3         5.28
#     4        12.74
#              ...
#     99995    14.58
#     99996     9.02
#     99997     2.57
#     99998     9.81
#     99999    15.93
#     Name: insulin_level, Length: 100000, dtype: float64
#
# In \[28\]:
#
#     plt.figure(figsize=(10,5))
#     plt.boxplot(df["insulin_level"])
#     plt.title("INSULIN LEVEL")
#     plt.xlabel("features")
#     plt.ylabel("values")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[29\]:
#
#     plt.figure(figsize=(10,5))
#     plt.boxplot(df["triglycerides"])
#     plt.title("TRIGLYCERIDES")
#     plt.xlabel("features")
#     plt.ylabel("values")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[30\]:
#
#     plt.figure(figsize=(10,5))
#     plt.boxplot(df["cholesterol_total"])
#     plt.title("cholesterol total")
#     plt.xlabel("features")
#     plt.ylabel("values")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[31\]:
#
#     plt.figure(figsize=(10,5))
#     plt.boxplot(df["waist_to_hip_ratio"])
#     plt.title("waist to hip ratio")
#     plt.xlabel("features")
#     plt.ylabel("values")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# -   outliers are present in all four variables,as shown by the points
#     outside the whishkers in the boxplots
#
# ## SECTION 4: BIVARIATE ANALYSIS-NUMERIC vs TARGET<a href="#SECTION-4:-BIVARIATE-ANALYSIS-NUMERIC-vs-TARGET"
# class="anchor-link">¶</a>
#
# ### QS 14<a href="#QS-14" class="anchor-link">¶</a>
#
# In \[32\]:
#
#     df.boxplot(column="hba1c",by="diagnosed_diabetes")
#
# Out\[32\]:
#
#     <Axes: title={'center': 'hba1c'}, xlabel='diagnosed_diabetes'>
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# ### QS 15<a href="#QS-15" class="anchor-link">¶</a>
#
# In \[33\]:
#
#     df.boxplot(column="glucose_fasting",by="diagnosed_diabetes")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[34\]:
#
#     df.boxplot(column="bmi",by="diagnosed_diabetes")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[35\]:
#
#     df.boxplot(column="diabetes_risk_score",by="diagnosed_diabetes")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# ### QS 16<a href="#QS-16" class="anchor-link">¶</a>
#
# In \[36\]:
#
#     plt.scatter(df["glucose_fasting"],df["glucose_postprandial"],c=df["diagnosed_diabetes"])
#     plt.xlabel("glucose_fasting")
#     plt.ylabel("glucose_postprandial")
#     plt.title("Glucose fasting vs Glucose postprandial")
#
# Out\[36\]:
#
#     Text(0.5, 1.0, 'Glucose fasting vs Glucose postprandial')
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# ### QS 17<a href="#QS-17" class="anchor-link">¶</a>
#
# In \[37\]:
#
#     plt.scatter(df["age"],df["diabetes_risk_score"])
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# ## SECTION 5: BIVARIATE ANALYSIS-CATEGORICAL VS TARGET<a href="#SECTION-5:-BIVARIATE-ANALYSIS-CATEGORICAL-VS-TARGET"
# class="anchor-link">¶</a>
#
# ### QS 19<a href="#QS-19" class="anchor-link">¶</a>
#
# In \[38\]:
#
#     df.groupby("smoking_status")["diagnosed_diabetes"].mean()*100
#
# Out\[38\]:
#
#     smoking_status
#     Current    60.006939
#     Former     60.111938
#     Never      59.956866
#     Name: diagnosed_diabetes, dtype: float64
#
# In \[39\]:
#
#     (df.groupby("smoking_status")["diagnosed_diabetes"].mean()*100).plot(kind="bar")
#     plt.xlabel("Smoking Status")
#     plt.ylabel("Diabetes Diagosis Rate(%)")
#     plt.title("DIABETES DIAGNOSIS RATE BY SMOKING STATUS")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# The diabetes diagnosis rates are nearly the same across all smoking
# status categories (Current, Former, and Never). There is no clear
# visible trend, as the differences between the categories are very small.
# This suggests that smoking status does not appear to have a strong
# association with diabetes diagnosis in this dataset.
#
# ## QS 20<a href="#QS-20" class="anchor-link">¶</a>
#
# In \[40\]:
#
#     df.groupby("income_level")["diagnosed_diabetes"].mean()*100
#
# Out\[40\]:
#
#     income_level
#     High            60.715714
#     Low             60.053945
#     Lower-Middle    60.385686
#     Middle          59.669436
#     Upper-Middle    59.866103
#     Name: diagnosed_diabetes, dtype: float64
#
# In \[41\]:
#
#     (df.groupby("income_level")["diagnosed_diabetes"].mean()*100).plot(kind="bar",color="brown",edgecolor="black")
#     plt.xlabel("Income Level")
#     plt.ylabel("Diabetes Diagosis Rate(%)")
#     plt.title("DIABETES DIAGNOSIS RATE BY INCOME LEVEL")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# In \[42\]:
#
#     df.groupby("education_level")["diagnosed_diabetes"].mean()*100
#
# Out\[42\]:
#
#     education_level
#     Graduate        60.119302
#     Highschool      60.067720
#     No formal       60.450980
#     Postgraduate    59.350788
#     Name: diagnosed_diabetes, dtype: float64
#
# In \[43\]:
#
#     (df.groupby("education_level")["diagnosed_diabetes"].mean()*100).plot(kind="bar",color="pink",edgecolor="g")
#     plt.xlabel("Education Level")
#     plt.ylabel("Diabetes Diagosis Rate(%)")
#     plt.title("DIABETES DIAGNOSIS RATE BY EDUCATION LEVEL")
#     plt.show()
#
# ![No description has been provided for this
# image](data:image/png;base64,...)
#
# The diabetes diagnosis rates are very similar across different income
# levels and education levels. There is no strong or clear trend among the
# categories. Therefore, socioeconomic factors do not appear to be
# strongly related to diabetes prevalence in this dataset, although there
# are small differences between some groups.
#
# In \[ \]:
