# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\SANITHA\Documents\data analytics\ONLINE EDUCATION SYSTEM REVIEW.csv")

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# The education sector plays an important role in the development of individuals and society. With the growth of technology, online education has become an important part of modern learning. Students now use different devices and online platforms to attend classes, study, interact with teachers, and clear their doubts. Factors such as internet facility, study time, social media usage, online interaction, and satisfaction can affect the learning experience. This project uses data analysis to understand students' online education experience and identify the major factors influencing their performance and satisfaction.

# %% [markdown]
# # PROBLEM STATEMENT: ANALYSIS OF ONLINE EDUCATION

# %% [markdown]
# - The rapid growth of online education has changed the way students learn and interact with teachers.
# - Students may face challenges related to internet facilities and devices used for online learning.
# - Study habits and social media usage can influence the online learning experience.
# - Online interaction and doubt clearing with faculties are important factors in online education.
# - These factors may affect students' overall learning experience, performance, and satisfaction.
# - This project analyses students' online education data to identify important patterns and relationships.
# - The analysis helps to understand the major challenges and characteristics of online learning among students.

# %% [markdown]
# # OBJECTIVES OF THE ONLINE EDUCATION

# %% [markdown]
# - To analyse the students’ online education experience using data analytics.
# - To understand the factors affecting students’ satisfaction with online education.
# - To analyse the impact of internet facilities and devices used for online learning.
# - To study students’ study time, sleep time, social media usage and gaming habits.
# - To examine the relationship between online interaction, doubt clearing and satisfaction.
# - To identify important patterns and trends in the online education data.
# - To derive meaningful insights that can help improve the online learning experience.

# %%
df
# Out:
#       Gender Home Location Level of Education  Age(Years)  Number of Subjects  \
# 0       Male         Urban     Under Graduate          18                  11
# 1       Male         Urban     Under Graduate          19                   7
# 2       Male         Rural     Under Graduate          18                   5
# 3       Male         Urban     Under Graduate          18                   5
# 4       Male         Rural     Under Graduate          18                   5
# ...      ...           ...                ...         ...                 ...
# 1028  Female         Rural     Under Graduate          19                   3
# 1029  Female         Rural     Under Graduate          20                   6
# 1030  Female         Rural     Under Graduate          20                   3
# 1031  Female         Rural     Under Graduate          19                   6
# 1032  Female         Urban     Under Graduate          20                   6
#
# ...

# %% [markdown]
# # DATA UNDERSTANDING

# %%
df.head()
# Out:
#   Gender Home Location Level of Education  Age(Years)  Number of Subjects  \
# 0   Male         Urban     Under Graduate          18                  11
# 1   Male         Urban     Under Graduate          19                   7
# 2   Male         Rural     Under Graduate          18                   5
# 3   Male         Urban     Under Graduate          18                   5
# 4   Male         Rural     Under Graduate          18                   5
#
#   Device type used to attend classes Economic status  Family size  \
# 0                             Laptop    Middle Class            4
# 1                             Laptop    Middle Class            4
# 2                             Laptop    Middle Class            5
# 3                             Laptop    Middle Class            4
# 4                             Laptop    Middle Class            4
#
#    Internet facility in your locality Are you involved in any sports?  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Home Location', 'Level of Education', 'Age(Years)',
#        'Number of Subjects', 'Device type used to attend classes',
#        'Economic status', 'Family size', 'Internet facility in your locality',
#        'Are you involved in any sports?', 'Do elderly people monitor you?',
#        'Study time (Hours)', 'Sleep time (Hours)',
#        'Time spent on social media (Hours)', 'Interested in Gaming?',
#        'Have separate room for studying?', 'Engaged in group studies?',
#        'Average marks scored before pandemic in traditional classroom',
#        'Your interaction in online mode',
#        'Clearing doubts with faculties in online mode', 'Interested in?',
#        'Performance in online',
#        'Your level of satisfaction in Online Education'],
#       dtype='object')

# %%
df.shape
# Out:
# (1033, 23)

# %%
df.size
# Out:
# 23759

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 23 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Gender                                                         1033 non-null   object
#  1   Home Location                                                  1033 non-null   object
#  2   Level of Education                                             1033 non-null   object
#  3   Age(Years)                                                     1033 non-null   int64
#  4   Number of Subjects                                             1033 non-null   int64
#  5   Device type used to attend classes                             1033 non-null   object
#  6   Economic status                                                1033 non-null   object
# ...

# %%
df.dtypes
# Out:
# Gender                                                           object
# Home Location                                                    object
# Level of Education                                               object
# Age(Years)                                                        int64
# Number of Subjects                                                int64
# Device type used to attend classes                               object
# Economic status                                                  object
# Family size                                                       int64
# Internet facility in your locality                                int64
# Are you involved in any sports?                                  object
# Do elderly people monitor you?                                   object
# Study time (Hours)                                                int64
# Sleep time (Hours)                                                int64
# ...

# %%
df.describe()
# Out:
#         Age(Years)  Number of Subjects  Family size  \
# count  1033.000000          1033.00000  1033.000000
# mean     19.798645             7.03485     4.413359
# std       3.199158             2.81034     1.236750
# min       9.000000             1.00000     2.000000
# 25%      18.000000             6.00000     4.000000
# 50%      19.000000             7.00000     4.000000
# 75%      20.000000             8.00000     5.000000
# max      40.000000            20.00000    10.000000
#
#        Internet facility in your locality  Study time (Hours)  \
# count                         1033.000000         1033.000000
# mean                             3.586641            4.325266
# std                              1.026063            2.134233
# min                              1.000000            1.000000
# 25%                              3.000000            3.000000
# 50%                              4.000000            4.000000
# ...

# %% [markdown]
# # DATA CLEANING

# %%
df.isnull().sum()
# Out:
# Gender                                                           0
# Home Location                                                    0
# Level of Education                                               0
# Age(Years)                                                       0
# Number of Subjects                                               0
# Device type used to attend classes                               0
# Economic status                                                  0
# Family size                                                      0
# Internet facility in your locality                               0
# Are you involved in any sports?                                  0
# Do elderly people monitor you?                                   0
# Study time (Hours)                                               0
# Sleep time (Hours)                                               0
# Time spent on social media (Hours)                               0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Gender                                                            2
# Home Location                                                     2
# Level of Education                                                3
# Age(Years)                                                       24
# Number of Subjects                                               20
# Device type used to attend classes                                3
# Economic status                                                   3
# Family size                                                       9
# Internet facility in your locality                                5
# Are you involved in any sports?                                   2
# Do elderly people monitor you?                                    2
# Study time (Hours)                                               10
# Sleep time (Hours)                                               10
# Time spent on social media (Hours)                               10
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# ## 1. GENDER DISTRIBUTIONS

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      614
# Female    419
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
df["Gender"].value_counts().plot(kind="bar",color="purple",edgecolor="yellow")
plt.xlabel("Gender")
plt.ylabel("Number of students")
plt.title("GENDER DISTRIBUTION")
plt.show()

# %% [markdown]
# - The Dataset contains more male students than female students
# - Male students make up the majority of the respondents ofthe survey
# - This indicates that the dataset is male-dominated,which may influence the overall analysis.

# %% [markdown]
# ## 2. AGE DISTRIBUTIONS

# %%
df["Age(Years)"].describe()
# Out:
# count    1033.000000
# mean       19.798645
# std         3.199158
# min         9.000000
# 25%        18.000000
# 50%        19.000000
# 75%        20.000000
# max        40.000000
# Name: Age(Years), dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.hist(df["Age(Years)"],bins=10,color="g",edgecolor="black")
plt.xlabel("Age(Years)")
plt.ylabel("Number of students")
plt.title("AGE DISTRIBUTION")
plt.show()

# %% [markdown]
# - The dataset contains 1,033 students.
# - The average age of the students is 19.8 years.
# - Most students are between 18 and 20 years of age (25% = 18, Median = 19, 75% = 20).
# - The minimum age is 9 years and the maximum age is 40 years, but only a few students belong to these extreme age groups.

# %% [markdown]
# ## 3. HOME LOCATION

# %%
df["Home Location"].value_counts()
# Out:
# Home Location
# Urban    679
# Rural    354
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df["Home Location"].value_counts().plot(kind="bar",color="brown",edgecolor="g")
plt.xlabel("Home Location")
plt.ylabel("Number of students")
plt.title("HOME LOCATION DISTRIBUTION")
plt.show()

# %% [markdown]
# - The dataset shows that 679 students are from urban areas, while 354 students are from rural areas.
# - Students from urban locations make up the majority of the respondents.
# - This indicates that urban students had higher participation in the online education survey than rural students.

# %% [markdown]
# ## 4. EDUCATION LEVEL

# %%
df["Level of Education"].value_counts()
# Out:
# Level of Education
# Under Graduate    817
# Post Graduate     129
# School             87
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df["Level of Education"].value_counts().plot(kind="bar",color="Blue",edgecolor="g")
plt.xlabel("Level of Education")
plt.ylabel("Number of students")
plt.title("LEVEL OF EDUCATION DISTRIBUTION")
plt.show()

# %% [markdown]
# - The majority of the respondents are Undergraduate students (817).
# - Postgraduate (129) and School students (87) make up a much smaller proportion of the dataset.
# - This indicates that the survey primarily represents undergraduate students, so the findings mainly reflect their online learning experience.

# %% [markdown]
# ## 5. DEVICE USED

# %%
df["Device type used to attend classes"].value_counts()
# Out:
# Device type used to attend classes
# Laptop     672
# Mobile     334
# Desktop     27
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
df["Device type used to attend classes"].value_counts().plot(kind="pie",autopct="%1.1f%%")
plt.xlabel("Device type used to attend classes")
plt.ylabel("")
plt.title("Device Type Used To Attend Classes")
plt.show()

# %% [markdown]
# - Most students attended online classes using laptops (672 students).
# - Mobile phones (334 students) were the second most commonly used device.
# - Desktop computers (27 students) were used by only a small number of students.
# - This indicates that laptops were the preferred device for online learning.

# %% [markdown]
# ## 6. ECONOMIC STATUS

# %%
df["Economic status"].value_counts()
# Out:
# Economic status
# Middle Class    954
# Poor             49
# Rich             30
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
df["Economic status"].value_counts().plot(kind="bar",color="orange",edgecolor="r")
plt.xlabel("Economic status")
plt.ylabel("Number of students")
plt.title("ECONOMIC STATUS DISTRIBUTION")
plt.show()

# %% [markdown]
# - The majority of the students (954) belong to the middle-class economic group.
# - Only 49 students belong to the poor category, while 30 students belong to the rich category.
# - This indicates that the survey mainly represents students from middle-class families, with comparatively fewer respondents from poor and rich backgrounds.

# %% [markdown]
# ## 7.FAMILY SIZE

# %%
df["Family size"].value_counts()
# Out:
# Family size
# 4     569
# 5     192
# 3     128
# 6      87
# 10     18
# 7      14
# 2      11
# 8       9
# 9       5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,6))
df["Family size"].value_counts().sort_index().plot(kind="bar",color="olive",edgecolor="white")
plt.xlabel("Family size")
plt.ylabel("Number of Students")
plt.title("FAMILY SIZE DISTRIBUTION")
plt.show()

# %% [markdown]
# - The majority of students belong to 4-member families (569).
# - This is followed by 5-member families (192), 3-member families (128), and 6-member families (87).
# - Very few students belong to families with 7 or more members.
# - This indicates that most respondents come from small to medium-sized families, with 4-member families being the most common.

# %% [markdown]
# ## 8. INTERNET FACILITY

# %%
df["Internet facility in your locality"].value_counts()
# Out:
# Internet facility in your locality
# 4    353
# 3    326
# 5    213
# 2    109
# 1     32
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,6))
df["Internet facility in your locality"].sort_index().value_counts().plot(kind="pie",autopct="%1.1f%%",startangle=90)
plt.ylabel("")
plt.title("INTERNET FACILITY")
plt.show()

# %% [markdown]
# - Most students rated their internet facility as 4 (353 students), indicating good internet connectivity.
# - A large number of students also gave a rating of 3 (326 students).
# - 213 students rated their internet facility as 5, showing excellent connectivity.
# - Only a small number of students gave ratings of 2 (109) and 1 (32).
# - This indicates that the majority of students had good to excellent internet access for online education.

# %% [markdown]
# ## 9. SPORTS PARTICIPATION

# %%
df["Are you involved in any sports?"].value_counts()
# Out:
# Are you involved in any sports?
# No     663
# Yes    370
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,6))
df["Are you involved in any sports?"].value_counts().plot(kind="pie",autopct="%1.1f%%",startangle=90)
plt.ylabel("")
plt.title("SPORTS PARTICIPACTION")
plt.show()

# %% [markdown]
# - 663 students (64.2%) are not involved in sports activities.
# - 370 students (35.8%) are involved in sports.
# - This indicates that the majority of the respondents do not participate in sports, while only about one-third take part in sports activities.

# %% [markdown]
# ## 10. SOCIAL MEDIA USAGE

# %%
df["Time spent on social media (Hours)"].value_counts()
# Out:
# Time spent on social media (Hours)
# 2     340
# 1     294
# 3     181
# 4      92
# 5      49
# 6      26
# 10     19
# 8      16
# 7      12
# 9       4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Time spent on social media (Hours)"],
         bins=10,
         color="Teal",
         edgecolor="silver")

plt.xlabel("Hours")
plt.ylabel("Number of Students")
plt.title("TIME SPENT ON SOCIAL MEDIA")
plt.show()

# %% [markdown]
# - Most students spend 2 hours (340 students) per day on social media.
# - 294 students spend 1 hour, while 181 students spend 3 hours daily.
# - Only a small number of students spend 5 or more hours on social media each day.
# - This indicates that most students use social media for a moderate amount of time (1–3 hours per day).

# %% [markdown]
# ## 11.GAMING INTEREST

# %%
df["Interested in Gaming?"].value_counts()
# Out:
# Interested in Gaming?
# Yes    560
# No     473
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
df["Interested in Gaming?"].value_counts().plot(kind="pie",autopct="%1.1f%%",startangle=90)
plt.title("GAMING INTEREST")
plt.ylabel("")
plt.show()

# %% [markdown]
# - 560 students (54.2%) are interested in gaming.
# - 473 students (45.8%) are not interested in gaming.
# - The difference between the two groups is small, but gaming interest is slightly higher than non-interest.
# - This indicates that more than half of the students have an interest in gaming, making it a common recreational activity among the respondents.

# %% [markdown]
# ##  12. SEPERATE STUDY ROOM

# %%
df["Have separate room for studying?"].value_counts()
# Out:
# Have separate room for studying?
# Yes    608
# No     425
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
df["Have separate room for studying?"].value_counts().plot(kind="pie",autopct="%1.1f%%",startangle=75)
plt.title("SEPARATE ROOM FOR STUDYING")
plt.ylabel("")
plt.show()

# %% [markdown]
# - 608 students (58.9%) have a separate room for studying.
# - 425 students (41.1%) do not have a separate room for studying.
# - This indicates that the majority of students have a dedicated study space at home, which may provide a better learning environment and support academic performance.

# %% [markdown]
# ## 13.GROUP STUDIES ENGAGED

# %%
df["Engaged in group studies?"].value_counts()
# Out:
# Engaged in group studies?
# No     616
# yes    417
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
df["Engaged in group studies?"].value_counts().plot(kind="pie",autopct="%1.1f%%",startangle=75)
plt.title("GROUP STUDIES")
plt.ylabel("")
plt.show()

# %% [markdown]
# - 616 students (59.6%) are not engaged in group studies.
# - 417 students (40.4%) are engaged in group studies.
# - This indicates that the majority of students prefer to study individually rather than in groups.

# %% [markdown]
# ## 14. MARKS BEFORE PANDEMIC

# %%
df["Average marks scored before pandemic in traditional classroom"].describe()
# Out:
# count      1033
# unique       10
# top       81-90
# freq        343
# Name: Average marks scored before pandemic in traditional classroom, dtype: object

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Average marks scored before pandemic in traditional classroom"],bins=10,color="lime",edgecolor="b")
plt.xlabel("MARKS")
plt.ylabel("Number of Students")
plt.title("AVERAGE MARKS SCORED BEFORE PANDEMIC")
plt.show()

# %% [markdown]
# - The dataset contains 1033 records with 10 unique categories.
# - The most common category is 81–90, which appears 343 times.
# - This indicates that the 81–90 group has the highest representation among all categories, showing a concentration of data in this range.

# %% [markdown]
# ## 15. INTERACTION IN ONLINE MODE

# %%
df["Your interaction in online mode"].value_counts()
# Out:
# Your interaction in online mode
# 3    433
# 4    189
# 2    189
# 1    129
# 5     93
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,6))
df["Your interaction in online mode"].value_counts().sort_index().plot(kind="bar",color="b",edgecolor="olive")
plt.xlabel("Level of interaction")
plt.ylabel("Number of Students")
plt.title("INTERACTION IN ONLINE MODE")
plt.show()

# %% [markdown]
# - 433 students gave a rating of 3, making it the most common interaction level.
# - 189 students rated their interaction as 4, while another 189 students rated it as 2.
# - 129 students gave a rating of 1, and only 93 students gave the highest rating of 5.
# - This indicates that most students experienced a moderate level of interaction in online learning.

# %% [markdown]
# ## 16. CLEARING DOUBTS

# %%
df["Clearing doubts with faculties in online mode"].value_counts().sort_index()
# Out:
# Clearing doubts with faculties in online mode
# 1    165
# 2    213
# 3    375
# 4    189
# 5     91
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,6))
df["Clearing doubts with faculties in online mode"].value_counts().sort_index().plot(kind="bar",color="black",edgecolor="b")
plt.xlabel("Level of doubt clearing")
plt.ylabel("Number of Students")
plt.title("Clearing doubts with faculties in online mode")
plt.show()

# %% [markdown]
# - 375 students gave a rating of 3, making it the most common response.
# - 213 students rated it 2, while 189 students rated it 4.
# - 165 students gave a rating of 1, and only 91 students gave the highest rating of 5.
# - This indicates that most students experienced a moderate level of interaction with faculties for clearing doubts in online mode.

# %% [markdown]
# ## 17. INTEREST IN ONLINE EDUCATION

# %%
df["Interested in?"].value_counts()
# Out:
# Interested in?
# Practical    439
# Both         347
# Theory       247
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,6))
df["Interested in?"].value_counts().plot(kind="bar",color="plum",edgecolor="g")
plt.xlabel("Interested Level")
plt.ylabel("Number of Students")
plt.title("INTERESTED EDUCATION TYPE")
plt.show()

# %% [markdown]
# - 439 students are interested in Practical education.
# - 347 students are interested in both Theory and Practical education.
# - 247 students are interested in Theory education.
# - This indicates that practical education is the most preferred type among the students, while theory-only education is the least preferred.

# %% [markdown]
# ## 18. SATISFACTION LEVEL

# %%
df["Your level of satisfaction in Online Education"].value_counts()
# Out:
# Your level of satisfaction in Online Education
# Average    541
# Good       251
# Bad        241
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,6))
df["Your level of satisfaction in Online Education"].value_counts().plot(kind="bar",color="tan",edgecolor="black")
plt.xlabel("satisfaction level")
plt.ylabel("Number of Students")
plt.title("SATISFACTION LEVEL")
plt.show()

# %% [markdown]
# # RELATIONSHIP ANALYSIS

# %% [markdown]
# ### 1-- INTERNET FACILITY IN YOUR LOCALITY   VS    YOUR LEVEL OF SATISFACTION IN ONLINE EDUCATION

# %%
ct=pd.crosstab(df["Internet facility in your locality"].astype(str),
df["Your level of satisfaction in Online Education"].astype(str))

# %%
ct
# Out:
# Your level of satisfaction in Online Education  Average  Bad  Good
# Internet facility in your locality
# 1                                                    11   17     4
# 2                                                    41   41    27
# 3                                                   193   62    71
# 4                                                   211   67    75
# 5                                                    85   54    74

# %%
ct=pd.crosstab(df["Internet facility in your locality"].astype(str),
df["Your level of satisfaction in Online Education"].astype(str))

ct.plot(kind="bar",stacked=True,figsize=(8,5))

plt.title("INTERNET FACILITY VS SATISFACTION")
plt.xlabel("Internet Facility")
plt.ylabel("Number of Students")
plt.legend(title="Satisfaction Level")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# - Students with Internet Facility level 4 have the highest number of respondents.
# - Average satisfaction is the most common satisfaction level across most internet facility categories.
# - Students with Internet Facility level 5 show a relatively higher proportion of Good satisfaction.
# - Overall, the chart suggests that better internet facilities are generally associated with higher satisfaction levels

# %% [markdown]
# ### 2--  DEVICE TYPE  VS  SATISFACTION

# %%
df["Device type used to attend classes"].value_counts()
# Out:
# Device type used to attend classes
# Laptop     672
# Mobile     334
# Desktop     27
# Name: count, dtype: int64

# %%
pd.crosstab(df["Device type used to attend classes"],
df["Your level of satisfaction in Online Education"])
# Out:
# Your level of satisfaction in Online Education  Average  Bad  Good
# Device type used to attend classes
# Desktop                                              15    5     7
# Laptop                                              352  187   133
# Mobile                                              174   49   111

# %%
ct=pd.crosstab(df["Device type used to attend classes"],
df["Your level of satisfaction in Online Education"])

ct.plot(kind="bar",stacked=True,figsize=(8,5))

plt.title("DEVICE TYPE VS SATISFACTION")
plt.xlabel("Device type used to attend classes")
plt.ylabel("Number of Students")
plt.legend(title="Satisfaction Level")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# - The analysis shows that laptop users are the majority and have the highest number of students across all satisfaction levels.
# - Mobile users are the second-largest group, while desktop users are very few.
# - Among all device users, Average satisfaction is the most common level, followed by Bad and Good satisfaction.

# %% [markdown]
# ### 3--ECONOMIC STATUS VS SATISFACTION

# %%
df["Economic status"].value_counts()
# Out:
# Economic status
# Middle Class    954
# Poor             49
# Rich             30
# Name: count, dtype: int64

# %%
pd.crosstab(df["Economic status"],
df["Your level of satisfaction in Online Education"])
# Out:
# Your level of satisfaction in Online Education  Average  Bad  Good
# Economic status
# Middle Class                                        505  220   229
# Poor                                                 25   11    13
# Rich                                                 11   10     9

# %%
ct=pd.crosstab(df["Economic status"],
df["Your level of satisfaction in Online Education"])

ct.plot(kind="bar",stacked=True,figsize=(8,5))

plt.title("ECONOMIC STATUS VS SATISFACTION")
plt.xlabel("ECONOMIC STATUS")
plt.ylabel("Number of Students")
plt.legend(title="Satisfaction Level")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# - The Middle Class group has the highest number of students.
# - Among them, Average satisfaction is the most common, followed by Good and Bad satisfaction levels.
# - The Poor group also shows the highest number of students with Average satisfaction, while the Rich group has a more balanced distribution across the three satisfaction levels.

# %% [markdown]
# ### 4-- ONLINE INTERACTION VS SATISFACTION

# %%
pd.crosstab(df["Your interaction in online mode"],
df["Your level of satisfaction in Online Education"])
# Out:
# Your level of satisfaction in Online Education  Average  Bad  Good
# Your interaction in online mode
# 1                                                    34   86     9
# 2                                                   100   74    15
# 3                                                   285   65    83
# 4                                                    99   14    76
# 5                                                    23    2    68

# %%
ct=pd.crosstab(df["Your interaction in online mode"],
df["Your level of satisfaction in Online Education"])

ct.plot(kind="bar",stacked=True,figsize=(8,5))

plt.title("ONLINE INTERACTION VS SATISFACTION")
plt.xlabel("INTERACTION LEVEL")
plt.ylabel("Number of Students")
plt.legend(title="Satisfaction Level")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# - The analysis shows that moderate online interaction (Level 3) has the highest number of students, with Average satisfaction being the most common.
# - At higher interaction levels (4 and 5), the proportion of students with Good satisfaction increases.
# - At Level 5, Good satisfaction is particularly high.

# %% [markdown]
# ### 5--CLEARING DOUBTS VS SATISFACTION

# %%
df["Clearing doubts with faculties in online mode"].value_counts()
# Out:
# Clearing doubts with faculties in online mode
# 3    375
# 2    213
# 4    189
# 1    165
# 5     91
# Name: count, dtype: int64

# %%
pd.crosstab(df["Clearing doubts with faculties in online mode"],
df["Your level of satisfaction in Online Education"])
# Out:
# Your level of satisfaction in Online Education  Average  Bad  Good
# Clearing doubts with faculties in online mode
# 1                                                    54  102     9
# 2                                                   112   80    21
# 3                                                   246   44    85
# 4                                                   102   15    72
# 5                                                    27    0    64

# %%
ct=pd.crosstab(df["Clearing doubts with faculties in online mode"],
df["Your level of satisfaction in Online Education"])

ct.plot(kind="bar",stacked=True,figsize=(8,5))

plt.title("CLEARING DOUBT VS SATISFACTION")
plt.xlabel("DOUBT CLEARING LEVEL")
plt.ylabel("Number of Students")
plt.legend(title="Satisfaction Level")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# - The analysis shows that Level 3 has the highest number of students, and Average satisfaction is the most common at this level.
# - As the doubt-clearing level increases (4 and 5), the number of students with Good satisfaction also increases.
# - At Level 5, Good satisfaction is particularly high, while Bad satisfaction is zero.

# %% [markdown]
# # CORRELATION

# %%
num = df.select_dtypes(include="number")

# %%
num
# Out:
#       Age(Years)  Number of Subjects  Family size  \
# 0             18                  11            4
# 1             19                   7            4
# 2             18                   5            5
# 3             18                   5            4
# 4             18                   5            4
# ...          ...                 ...          ...
# 1028          19                   3            6
# 1029          20                   6            3
# 1030          20                   3            3
# 1031          19                   6            2
# 1032          20                   6            4
#
#       Internet facility in your locality  Study time (Hours)  \
# 0                                      5                   3
# 1                                      1                   7
# 2                                      2                   6
# 3                                      4                   3
# ...

# %%
df.dtypes
# Out:
# Gender                                                           object
# Home Location                                                    object
# Level of Education                                               object
# Age(Years)                                                        int64
# Number of Subjects                                                int64
# Device type used to attend classes                               object
# Economic status                                                  object
# Family size                                                       int64
# Internet facility in your locality                                int64
# Are you involved in any sports?                                  object
# Do elderly people monitor you?                                   object
# Study time (Hours)                                                int64
# Sleep time (Hours)                                                int64
# ...

# %%
num = df.select_dtypes(include="number")
corr =num.corr()

plt.figure(figsize=(12,8))
plt.imshow(corr,cmap="coolwarm",aspect="auto")
plt.colorbar()

plt.xticks(range(len(corr.columns)),corr.columns,rotation=90)
plt.yticks(range(len(corr.columns)),corr.columns)
plt.title("CORRELATION HEATMAP")

for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        plt.text(j,i,round(corr.iloc[i,j],2),ha="center",va="center")
plt.show()

# %% [markdown]
# - Online interaction and clearing doubts with faculties show a strong positive correlation (0.72).
# - Online interaction and online performance show a positive correlation (0.56).
# - Clearing doubts with faculties and online performance also show a positive correlation (0.56).
# - Internet facility has a moderate positive relationship with online performance (0.26).
# - Study time has a weak positive relationship with online performance (0.13).
# - Other factors such as age, family size, sleep time, and social media usage show weak correlations with online performance.

# %% [markdown]
# # KPI (KEY PERFORMANCE INDICATORS)

# %% [markdown]
# ### 1. TOTAL STUDENTS

# %%
df.shape[0]
# Out:
# 1033

# %% [markdown]
# ### 2. AVERAGE AGE

# %%
df["Age(Years)"].mean()
# Out:
# np.float64(19.79864472410455)

# %% [markdown]
# ### 3. AVERAGE MARKS

# %%
df
# Out:
#       Gender Home Location Level of Education  Age(Years)  Number of Subjects  \
# 0       Male         Urban     Under Graduate          18                  11
# 1       Male         Urban     Under Graduate          19                   7
# 2       Male         Rural     Under Graduate          18                   5
# 3       Male         Urban     Under Graduate          18                   5
# 4       Male         Rural     Under Graduate          18                   5
# ...      ...           ...                ...         ...                 ...
# 1028  Female         Rural     Under Graduate          19                   3
# 1029  Female         Rural     Under Graduate          20                   6
# 1030  Female         Rural     Under Graduate          20                   3
# 1031  Female         Rural     Under Graduate          19                   6
# 1032  Female         Urban     Under Graduate          20                   6
#
# ...

# %%
df["Average marks scored before pandemic in traditional classroom"].head()
# Out:
# 0    91-100
# 1    91-100
# 2     71-80
# 3    91-100
# 4     81-90
# Name: Average marks scored before pandemic in traditional classroom, dtype: object

# %%
marks_col = "Average marks scored before pandemic in traditional classroom"

midpoints = {
    "0-10": 5,
    "11-20": 15,
    "21-30": 25,
    "31-40": 35,
    "41-50": 45,
    "51-60": 55,
    "61-70": 65,
    "71-80": 75,
    "81-90": 85,
    "91-100": 95
}

marks_numeric = df[marks_col].map(midpoints)

average_marks = marks_numeric.mean()

print("Average Marks:", round(average_marks, 2))
# Out:
# Average Marks: 77.35

# %% [markdown]
# ### 4. AVERAGE SOCIAL MEDIA HOURS

# %%
df["Time spent on social media (Hours)"].mean()
# Out:
# np.float64(2.6369796708615683)

# %% [markdown]
# ### 5. INTERNET FACILITY

# %%
(df["Internet facility in your locality"].isin([4,5]).mean()) * 100
# Out:
# np.float64(54.791868344627304)

# %% [markdown]
# ### 6. OVERALL SATISFACTION

# %%
(df["Your level of satisfaction in Online Education"] == "Good").mean() * 100
# Out:
# np.float64(24.298160696999034)

# %%
KPI=pd.DataFrame({"KPI":["TOTAL STUDENTS","AVERAGE AGE","AVERAGE MARKS","AVERAGE SOCIAL MEDIA HOURS ","INTERNET FACILITY%","OVERALL SATISFACTION %"],
                  "VALUE":[1033,19.80,77.35,2.64,54.79,24.30]})

# %%
KPI
# Out:
#                            KPI    VALUE
# 0               TOTAL STUDENTS  1033.00
# 1                  AVERAGE AGE    19.80
# 2                AVERAGE MARKS    77.35
# 3  AVERAGE SOCIAL MEDIA HOURS      2.64
# 4           INTERNET FACILITY%    54.79
# 5       OVERALL SATISFACTION %    24.30

# %% [markdown]
# - The dataset contains 1,033 students.
# - The average age of the students is 19.80 years.
# - The average marks scored before the pandemic are 77.35.
# - Students spend an average of 2.64 hours on social media.
# - About 54.79% of students have good internet facilities.
# - About 24.30% of students reported being satisfied with online education.

# %% [markdown]
# # MAIN FINDINGS

# %% [markdown]
# - The study analysed the online education experience of 1,033 students.
# - Laptop was the most commonly used device for attending online classes.
# - Most students belonged to the Middle Class economic group.
# - Average satisfaction was the most common satisfaction level among students.
# - Students with higher online interaction generally showed better satisfaction levels.
# - Better doubt clearing with faculties was associated with higher satisfaction.
# - Online interaction and doubt clearing showed a strong positive correlation (0.72).
# - The average marks scored before the pandemic were 77.35.
# - Students spent an average of 2.64 hours on social media per day.
# - Overall, internet facilities, online interaction, and faculty support were important aspects of the students' online education experience.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# This project analysed students experiences with online education using data analytics. The analysis showed that laptops were the most commonly used devices, and most students belonged to the middle-class group. The study also found that online interaction and clearing doubts with faculties had a strong positive relationship with online performance. Internet facility, study habits, and other factors also influenced the overall learning experience. Overall, the project highlights the importance of good internet access, effective interaction with teachers, and proper academic support in improving the online education experience and student performance.
