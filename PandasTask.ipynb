# %% [markdown]
# # PANDAS TASK

# %%
df=pd.read_csv(r"C:\Users\SANITHA\Documents\data analytics\review\files\employee_data.csv")

# %%
import pandas as pd

# %% [markdown]
# # SECTION A: DATA EXPLORATION

# %% [markdown]
# ## QS 1

# %%
df
# Out:
#     ID          Name Department      City        Job Role   Salary  Exp_Yrs  \
# 0    1    Arun Kumar      Sales   Calicut       Executive  28000.0        3
# 1    2    Priya Nair         IT     Kochi       Developer  45000.0        5
# 2    3   Rahul Menon         HR   Calicut         Manager  38000.0        7
# 3    4     Sneha Das      Sales  Thrissur       Executive  29000.0        2
# 4    5       Vijay S         IT     Kochi       Developer  47000.0        6
# ..  ..           ...        ...       ...             ...      ...      ...
# 58  59  Joseph Kumar    Finance  Thrissur  Senior Analyst  38500.0        7
# 59  60   Sreeja Devi    Finance   Calicut  Senior Analyst  48000.0       11
# 60  61    Priya Nair         IT     Kochi       Developer  45000.0        5
# 61  62       Anoop M         IT   Calicut       Developer  43000.0        5
# 62  63   Jishnu Devi         HR  Thrissur       Recruiter  26000.0       10
#
#     Rating
# 0      4.2
# 1      4.7
# 2      NaN
# ...

# %%
df.head()
# Out:
#    ID         Name Department      City   Job Role   Salary  Exp_Yrs  Rating
# 0   1   Arun Kumar      Sales   Calicut  Executive  28000.0        3     4.2
# 1   2   Priya Nair         IT     Kochi  Developer  45000.0        5     4.7
# 2   3  Rahul Menon         HR   Calicut    Manager  38000.0        7     NaN
# 3   4    Sneha Das      Sales  Thrissur  Executive  29000.0        2     3.9
# 4   5      Vijay S         IT     Kochi  Developer  47000.0        6     4.5

# %% [markdown]
# ## QS 2

# %%
df.shape
# Out:
# (63, 8)

# %% [markdown]
# ## QS 3

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Department', 'City', 'Job Role', 'Salary', 'Exp_Yrs',
#        'Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          63 non-null     int64
#  1   Name        58 non-null     object
#  2   Department  63 non-null     object
#  3   City        57 non-null     object
#  4   Job Role    63 non-null     object
#  5   Salary      62 non-null     float64
#  6   Exp_Yrs     63 non-null     int64
#  7   Rating      58 non-null     float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.1+ KB

# %%
df.isnull().sum()
# Out:
# ID            0
# Name          5
# Department    0
# City          6
# Job Role      0
# Salary        1
# Exp_Yrs       0
# Rating        5
# dtype: int64

# %% [markdown]
# ## QS 4

# %%
df.describe()
# Out:
#               ID        Salary    Exp_Yrs     Rating
# count  63.000000     62.000000  63.000000  58.000000
# mean   32.000000  38822.580645   6.063492   4.194828
# std    18.330303  12657.239480   3.267005   0.455925
# min     1.000000  25000.000000   1.000000   3.400000
# 25%    16.500000  28000.000000   3.000000   3.800000
# 50%    32.000000  34000.000000   6.000000   4.200000
# 75%    47.500000  46500.000000   9.000000   4.600000
# max    63.000000  65500.000000  12.000000   4.900000

# %%
df["Salary"].mean()
# Out:
# np.float64(38822.58064516129)

# %% [markdown]
# ## QS 5

# %%
df.value_counts()
# Out:
# ID  Name                Department  City      Job Role          Salary   Exp_Yrs  Rating
# 1   Arun Kumar          Sales       Calicut   Executive         28000.0  3        4.2       1
# 52  Naveen C            IT          Calicut   Lead              63500.0  6        4.6       1
# 39  Naveen K            Finance     Kannur    Analyst           34000.0  8        4.6       1
# 42  Sneha Nair          HR          Palakkad  Manager           29000.0  1        4.8       1
# 43  Ajay Das            IT          Palakkad  Lead              58500.0  10       3.5       1
# 44  Jishnu Devi         HR          Thrissur  Executive         32000.0  7        3.6       1
# 45  Sajith Mathew       Sales       Palakkad  Executive         26000.0  9        3.7       1
# 46  Nimisha R           HR          Kannur    Recruiter         33500.0  10       4.9       1
# 47  Fathima K           Sales       Calicut   Executive         33500.0  3        3.8       1
# ...

# %%
df.size
# Out:
# 504

# %% [markdown]
# ## QS 6

# %%
df["Department"].unique()
# Out:
# array(['Sales', 'IT', 'HR', 'Finance'], dtype=object)

# %% [markdown]
# ## QS 7

# %%
df["Department"].value_counts()
# Out:
# Department
# Sales      19
# IT         19
# HR         16
# Finance     9
# Name: count, dtype: int64

# %% [markdown]
# ## QS 8

# %%
df["City"].value_counts()
# Out:
# City
# Calicut     18
# Kochi       15
# Thrissur    12
# Palakkad     8
# Kannur       4
# Name: count, dtype: int64

# %% [markdown]
# ## QS 9

# %%
df["Job Role"].unique()
# Out:
# array(['Executive', 'Developer', 'Manager', 'Analyst', 'Lead',
#        'Senior Analyst', 'Senior Executive', 'Recruiter', 'QA Engineer',
#        'Senior Developer'], dtype=object)

# %% [markdown]
# ## QS 10

# %%
df[["Name","Department","Salary"]]
# Out:
#             Name Department   Salary
# 0     Arun Kumar      Sales  28000.0
# 1     Priya Nair         IT  45000.0
# 2    Rahul Menon         HR  38000.0
# 3      Sneha Das      Sales  29000.0
# 4        Vijay S         IT  47000.0
# ..           ...        ...      ...
# 58  Joseph Kumar    Finance  38500.0
# 59   Sreeja Devi    Finance  48000.0
# 60    Priya Nair         IT  45000.0
# 61       Anoop M         IT  43000.0
# 62   Jishnu Devi         HR  26000.0
#
# [63 rows x 3 columns]

# %% [markdown]
# # SECTION B: DATA CLEANING

# %% [markdown]
# ## QS 11

# %%
df
# Out:
#     ID          Name Department      City        Job Role   Salary  Exp_Yrs  \
# 0    1    Arun Kumar      Sales   Calicut       Executive  28000.0        3
# 1    2    Priya Nair         IT     Kochi       Developer  45000.0        5
# 2    3   Rahul Menon         HR   Calicut         Manager  38000.0        7
# 3    4     Sneha Das      Sales  Thrissur       Executive  29000.0        2
# 4    5       Vijay S         IT     Kochi       Developer  47000.0        6
# ..  ..           ...        ...       ...             ...      ...      ...
# 58  59  Joseph Kumar    Finance  Thrissur  Senior Analyst  38500.0        7
# 59  60   Sreeja Devi    Finance   Calicut  Senior Analyst  48000.0       11
# 60  61    Priya Nair         IT     Kochi       Developer  45000.0        5
# 61  62       Anoop M         IT   Calicut       Developer  43000.0        5
# 62  63   Jishnu Devi         HR  Thrissur       Recruiter  26000.0       10
#
#     Rating
# 0      4.2
# 1      4.7
# 2      NaN
# ...

# %%
df.isnull().sum()
# Out:
# ID            0
# Name          5
# Department    0
# City          6
# Job Role      0
# Salary        1
# Exp_Yrs       0
# Rating        5
# dtype: int64

# %% [markdown]
# ## QS 12

# %%
df
# Out:
#     ID          Name Department      City        Job Role   Salary  Exp_Yrs  \
# 0    1    Arun Kumar      Sales   Calicut       Executive  28000.0        3
# 1    2    Priya Nair         IT     Kochi       Developer  45000.0        5
# 2    3   Rahul Menon         HR   Calicut         Manager  38000.0        7
# 3    4     Sneha Das      Sales  Thrissur       Executive  29000.0        2
# 4    5       Vijay S         IT     Kochi       Developer  47000.0        6
# ..  ..           ...        ...       ...             ...      ...      ...
# 58  59  Joseph Kumar    Finance  Thrissur  Senior Analyst  38500.0        7
# 59  60   Sreeja Devi    Finance   Calicut  Senior Analyst  48000.0       11
# 60  61    Priya Nair         IT     Kochi       Developer  45000.0        5
# 61  62       Anoop M         IT   Calicut       Developer  43000.0        5
# 62  63   Jishnu Devi         HR  Thrissur       Recruiter  26000.0       10
#
#     Rating
# 0      4.2
# 1      4.7
# 2      NaN
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# Length: 63, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## QS 13

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# Length: 63, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#     ID          Name Department      City        Job Role   Salary  Exp_Yrs  \
# 0    1    Arun Kumar      Sales   Calicut       Executive  28000.0        3
# 1    2    Priya Nair         IT     Kochi       Developer  45000.0        5
# 2    3   Rahul Menon         HR   Calicut         Manager  38000.0        7
# 3    4     Sneha Das      Sales  Thrissur       Executive  29000.0        2
# 4    5       Vijay S         IT     Kochi       Developer  47000.0        6
# ..  ..           ...        ...       ...             ...      ...      ...
# 58  59  Joseph Kumar    Finance  Thrissur  Senior Analyst  38500.0        7
# 59  60   Sreeja Devi    Finance   Calicut  Senior Analyst  48000.0       11
# 60  61    Priya Nair         IT     Kochi       Developer  45000.0        5
# 61  62       Anoop M         IT   Calicut       Developer  43000.0        5
# 62  63   Jishnu Devi         HR  Thrissur       Recruiter  26000.0       10
#
#     Rating
# 0      4.2
# 1      4.7
# 2      NaN
# ...

# %%
df.shape
# Out:
# (63, 8)

# %%
drop=df.drop_duplicates()

# %%
drop.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (63, 8)

# %% [markdown]
# ## QS 14

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Department', 'City', 'Job Role', 'Salary', 'Exp_Yrs',
#        'Rating'],
#       dtype='object')

# %%
df=df.drop(columns=["ID"])

# %%
df
# Out:
#             Name Department      City        Job Role   Salary  Exp_Yrs  \
# 0     Arun Kumar      Sales   Calicut       Executive  28000.0        3
# 1     Priya Nair         IT     Kochi       Developer  45000.0        5
# 2    Rahul Menon         HR   Calicut         Manager  38000.0        7
# 3      Sneha Das      Sales  Thrissur       Executive  29000.0        2
# 4        Vijay S         IT     Kochi       Developer  47000.0        6
# ..           ...        ...       ...             ...      ...      ...
# 58  Joseph Kumar    Finance  Thrissur  Senior Analyst  38500.0        7
# 59   Sreeja Devi    Finance   Calicut  Senior Analyst  48000.0       11
# 60    Priya Nair         IT     Kochi       Developer  45000.0        5
# 61       Anoop M         IT   Calicut       Developer  43000.0        5
# 62   Jishnu Devi         HR  Thrissur       Recruiter  26000.0       10
#
#     Rating
# 0      4.2
# 1      4.7
# 2      NaN
# 3      3.9
# 4      4.5
# ..     ...
# 58     4.6
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Department', 'City', 'Job Role', 'Salary', 'Exp_Yrs',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# ## QS 15

# %%
df.isnull()
# Out:
#      Name  Department   City  Job Role  Salary  Exp_Yrs  Rating
# 0   False       False  False     False   False    False   False
# 1   False       False  False     False   False    False   False
# 2   False       False  False     False   False    False    True
# 3   False       False  False     False   False    False   False
# 4   False       False  False     False   False    False   False
# ..    ...         ...    ...       ...     ...      ...     ...
# 58  False       False  False     False   False    False   False
# 59  False       False  False     False   False    False   False
# 60  False       False  False     False   False    False   False
# 61  False       False  False     False   False    False   False
# 62  False       False  False     False   False    False   False
#
# [63 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Name          5
# Department    0
# City          6
# Job Role      0
# Salary        1
# Exp_Yrs       0
# Rating        5
# dtype: int64

# %%
print("Before:",df.shape)

df = df.dropna()

print("After:",df.shape)
# Out:
# Before: (63, 7)
# After: (47, 7)

# %% [markdown]
# ## QS 16

# %%
df
# Out:
#                   Name Department      City          Job Role   Salary  \
# 0           Arun Kumar      Sales   Calicut         Executive  28000.0
# 1           Priya Nair         IT     Kochi         Developer  45000.0
# 3            Sneha Das      Sales  Thrissur         Executive  29000.0
# 4              Vijay S         IT     Kochi         Developer  47000.0
# 7           Arun Kumar      Sales   Calicut         Executive  28000.0
# 8              Divya R         HR  Thrissur         Executive  26000.0
# 10             Anoop M         IT   Calicut         Developer  43000.0
# 12             Rajan T    Finance   Calicut    Senior Analyst  41000.0
# 15            Sreeja V         HR   Calicut         Executive  25000.0
# 17           Lakshmi G      Sales  Thrissur         Executive  27000.0
# 18          Arun Kumar      Sales   Calicut         Executive  28000.0
# 19            Jishnu C         IT     Kochi              Lead  65000.0
# ...

# %%
df["Salary"].isnull().sum()
# Out:
# np.int64(0)

# %%
df=df.dropna(subset=["Salary"])
print(df["Salary"].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## QS 17

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                   Name Department      City          Job Role   Salary  \
# 0           Arun Kumar      Sales   Calicut         Executive  28000.0
# 1           Priya Nair         IT     Kochi         Developer  45000.0
# 3            Sneha Das      Sales  Thrissur         Executive  29000.0
# 4              Vijay S         IT     Kochi         Developer  47000.0
# 8              Divya R         HR  Thrissur         Executive  26000.0
# 10             Anoop M         IT   Calicut         Developer  43000.0
# 12             Rajan T    Finance   Calicut    Senior Analyst  41000.0
# 15            Sreeja V         HR   Calicut         Executive  25000.0
# 17           Lakshmi G      Sales  Thrissur         Executive  27000.0
# 19            Jishnu C         IT     Kochi              Lead  65000.0
# 21            Jishnu M      Sales  Palakkad  Senior Executive  25000.0
# 22            Sreeja C      Sales  Thrissur           Manager  27000.0
# ...

# %%
it= df[df["Department"]== "IT"]
print(it[["Name", "Job Role"]])
print(it.shape[0])
# Out:
#            Name          Job Role
# 1    Priya Nair         Developer
# 4       Vijay S         Developer
# 10      Anoop M         Developer
# 19     Jishnu C              Lead
# 27    Pradeep G              Lead
# 34     Vishnu G       QA Engineer
# 36  Maya Thomas              Lead
# 42     Ajay Das              Lead
# 50  Sanjay Devi  Senior Developer
# 51     Naveen C              Lead
# 52      Kiran G       QA Engineer
# 56      Manoj C  Senior Developer
# 12

# %%
it
# Out:
#            Name Department      City          Job Role   Salary  Exp_Yrs  \
# 1    Priya Nair         IT     Kochi         Developer  45000.0        5
# 4       Vijay S         IT     Kochi         Developer  47000.0        6
# 10      Anoop M         IT   Calicut         Developer  43000.0        5
# 19     Jishnu C         IT     Kochi              Lead  65000.0       11
# 27    Pradeep G         IT    Kannur              Lead  48000.0        3
# 34     Vishnu G         IT  Thrissur       QA Engineer  56500.0        8
# 36  Maya Thomas         IT    Kannur              Lead  65000.0        8
# 42     Ajay Das         IT  Palakkad              Lead  58500.0       10
# 50  Sanjay Devi         IT   Calicut  Senior Developer  64500.0        9
# 51     Naveen C         IT   Calicut              Lead  63500.0        6
# 52      Kiran G         IT   Calicut       QA Engineer  47000.0        4
# 56      Manoj C         IT   Calicut  Senior Developer  59500.0        6
#
#     Rating
# ...

# %% [markdown]
# ## QS 18

# %%
df
# Out:
#                   Name Department      City          Job Role   Salary  \
# 0           Arun Kumar      Sales   Calicut         Executive  28000.0
# 1           Priya Nair         IT     Kochi         Developer  45000.0
# 3            Sneha Das      Sales  Thrissur         Executive  29000.0
# 4              Vijay S         IT     Kochi         Developer  47000.0
# 8              Divya R         HR  Thrissur         Executive  26000.0
# 10             Anoop M         IT   Calicut         Developer  43000.0
# 12             Rajan T    Finance   Calicut    Senior Analyst  41000.0
# 15            Sreeja V         HR   Calicut         Executive  25000.0
# 17           Lakshmi G      Sales  Thrissur         Executive  27000.0
# 19            Jishnu C         IT     Kochi              Lead  65000.0
# 21            Jishnu M      Sales  Palakkad  Senior Executive  25000.0
# 22            Sreeja C      Sales  Thrissur           Manager  27000.0
# ...

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\SANITHA\Documents\data analytics\review\files\employee_data.csv")

# %%
df.isnull().sum()
# Out:
# ID            0
# Name          5
# Department    0
# City          6
# Job Role      0
# Salary        1
# Exp_Yrs       0
# Rating        5
# dtype: int64

# %%
missing=df.isnull().sum
print(df.columns[df.isnull().sum() > 1])
# Out:
# Index(['Name', 'City', 'Rating'], dtype='object')

# %% [markdown]
# ## QS 19

# %%
df
# Out:
#     ID          Name Department      City        Job Role   Salary  Exp_Yrs  \
# 0    1    Arun Kumar      Sales   Calicut       Executive  28000.0        3
# 1    2    Priya Nair         IT     Kochi       Developer  45000.0        5
# 2    3   Rahul Menon         HR   Calicut         Manager  38000.0        7
# 3    4     Sneha Das      Sales  Thrissur       Executive  29000.0        2
# 4    5       Vijay S         IT     Kochi       Developer  47000.0        6
# ..  ..           ...        ...       ...             ...      ...      ...
# 58  59  Joseph Kumar    Finance  Thrissur  Senior Analyst  38500.0        7
# 59  60   Sreeja Devi    Finance   Calicut  Senior Analyst  48000.0       11
# 60  61    Priya Nair         IT     Kochi       Developer  45000.0        5
# 61  62       Anoop M         IT   Calicut       Developer  43000.0        5
# 62  63   Jishnu Devi         HR  Thrissur       Recruiter  26000.0       10
#
#     Rating
# 0      4.2
# 1      4.7
# 2      NaN
# ...

# %%
# remove duplicates rows

df.drop_duplicates
print(df.shape)

# drop id columns

df.drop("ID",axis=1, inplace=True)
print(df.shape)

# drop rows with null values

df.dropna(inplace=True)
print(df.shape)
# Out:
# (63, 8)
# (63, 7)
# (47, 7)

# %% [markdown]
# ## QS 20

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                   Name Department      City          Job Role   Salary  \
# 0           Arun Kumar      Sales   Calicut         Executive  28000.0
# 1           Priya Nair         IT     Kochi         Developer  45000.0
# 3            Sneha Das      Sales  Thrissur         Executive  29000.0
# 4              Vijay S         IT     Kochi         Developer  47000.0
# 8              Divya R         HR  Thrissur         Executive  26000.0
# 10             Anoop M         IT   Calicut         Developer  43000.0
# 12             Rajan T    Finance   Calicut    Senior Analyst  41000.0
# 15            Sreeja V         HR   Calicut         Executive  25000.0
# 17           Lakshmi G      Sales  Thrissur         Executive  27000.0
# 19            Jishnu C         IT     Kochi              Lead  65000.0
# 21            Jishnu M      Sales  Palakkad  Senior Executive  25000.0
# 22            Sreeja C      Sales  Thrissur           Manager  27000.0
# ...

# %%
df.groupby("Department").size()
# Out:
# Department
# Finance     6
# HR         11
# IT         12
# Sales      13
# dtype: int64

# %%
df["City"].unique()
# Out:
# array(['Calicut', 'Kochi', 'Thrissur', 'Palakkad', 'Kannur'], dtype=object)

# %%
df["Exp_Yrs"].mean()
# Out:
# np.float64(5.833333333333333)
